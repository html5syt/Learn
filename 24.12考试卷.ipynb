# %% [markdown]
# # T21

# %% [markdown]
# ![1.png](attachment:1.png)

# %%
import csv

i = 1
p = 1
s = 0
data = [["次数(i)", "s", "p"]]

while i <= 30:
    temp = []
    print("次数:", i)
    temp.append(i)
    s = s + p
    print("s:", s)
    temp.append(s)
    p = i
    print("p:", p)
    temp.append(p)
    i = i + 1
    data.append(temp)
print(s)
# 写入 CSV 文件
with open("result.csv", "w", newline="", encoding="ANSI") as file:
    writer = csv.writer(file)
    writer.writerows(data)
# Out:
# 次数: 1
# s: 1
# p: 1
# 次数: 2
# s: 2
# p: 2
# 次数: 3
# s: 4
# p: 3
# 次数: 4
# s: 7
# p: 4
# 次数: 5
# s: 11
# p: 5
# 次数: 6
# s: 16
# p: 6
# 次数: 7
# s: 22
# p: 7
# 次数: 8
# s: 29
# p: 8
# 次数: 9
# s: 37
# p: 9
# 次数: 10
# s: 46
# p: 10
# 次数: 11
# s: 56
# p: 11
# 次数: 12
# s: 67
# p: 12
# 次数: 13
# s: 79
# p: 13
# 次数: 14
# s: 92
# p: 14
# 次数: 15
# s: 106
# p: 15
# 次数: 16
# s: 121
# p: 16
# 次数: 17
# s: 137
# p: 17
# 次数: 18
# s: 154
# p: 18
# 次数: 19
# s: 172
# p: 19
# 次数: 20
# s: 191
# p: 20
# 次数: 21
# s: 211
# p: 21
# 次数: 22
# s: 232
# p: 22
# 次数: 23
# s: 254
# p: 23
# 次数: 24
# s: 277
# p: 24
# 次数: 25
# s: 301
# p: 25
# 次数: 26
# s: 326
# p: 26
# 次数: 27
# s: 352
# p: 27
# 次数: 28
# s: 379
# p: 28
# 次数: 29
# s: 407
# p: 29
# 次数: 30
# s: 436
# p: 30
# 436

# %% [markdown]
# ![image.png](attachment:image.png)
